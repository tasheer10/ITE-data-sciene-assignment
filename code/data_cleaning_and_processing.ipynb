# %%
import pandas as pd
import json
import os

# %%
base_path = '../source/'
# Load the datasets
visitors_df = pd.read_csv(os.path.join(base_path, 'visitors.csv'))
answers_df = pd.read_csv(os.path.join(base_path, 'visitors_answers.csv'))
questions_df = pd.read_csv(os.path.join(base_path, 'visitors_questions.csv'))
exhibitor_categories_df = pd.read_csv(os.path.join(base_path, 'exhibitor_categories.csv'))
exhibitors_df = pd.read_csv(os.path.join(base_path, 'exhibitors.csv'))

# %% [markdown]
# ## --- Processing Visitor Data ---

# %%
visitors_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   email   100 non-null    object
#  1   gender  100 non-null    object
#  2   id      100 non-null    object
#  3   data    100 non-null    object
# dtypes: object(4)
# memory usage: 3.3+ KB

# %%
visitors_df.head()
# Out:
#                                       email gender                        id  \
# 0                   emilija+100_L8gA@bss.mk      F  67b70a9f2d21f543a1096602
# 1   aleksandar.dimkov+mitt1_n5eA@bss.com.mk      M  67ada1ee197e604dd2722d1b
# 2             daniela.p+150_YhiF@bss.com.mk      F  67b44fef197e604dd2722d3d
# 3                 tanja+182_jiPa@bss.com.mk      F  67b45018197e604dd2722d3e
# 4  aleksandar.dimkov+mitt10_V0iB@bss.com.mk      M  67b5f1392d21f543a10965f1
#
#                                                 data
# 0  [{ "stepId" : "5c8a78336d41a10da4f730ef", "que...
# 1  [{ "stepId" : "5c8a78336d41a10da4f730ef", "que...
# 2  [{ "stepId" : "5c8a78336d41a10da4f730ef", "que...
# 3  [{ "stepId" : "5c8a78336d41a10da4f730ef", "que...
# 4  [{ "stepId" : "5c8a78336d41a10da4f730ef", "que...

# %%
answers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          43 non-null     object
#  1   answer      43 non-null     object
#  2   questionId  43 non-null     object
# dtypes: object(3)
# memory usage: 1.1+ KB

# %%
answers_df.head()
# Out:
#                          id                            answer  \
# 0  5c8a78336d41a10da4f73103                 Personal interest
# 1  5c8a78336d41a10da4f73100     To obtain general information
# 2  5c8a78336d41a10da4f730ff   To source products and services
# 3  5c8a78336d41a10da4f73101  To promote products and services
# 4  5c8a78336d41a10da4f73102             Educational purposes
#
#                  questionId
# 0  5c8a78336d41a10da4f730fe
# 1  5c8a78336d41a10da4f730fe
# 2  5c8a78336d41a10da4f730fe
# 3  5c8a78336d41a10da4f730fe
# 4  5c8a78336d41a10da4f730fe

# %%
print(f"Missing answers: {answers_df['answer'].isnull().sum()}")
# Out:
# Missing answers: 0

# %%
questions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              5 non-null      object
#  1   questionTypeId  5 non-null      object
#  2   stepId          5 non-null      object
#  3   question        5 non-null      object
# dtypes: object(4)
# memory usage: 292.0+ bytes

# %%
#Process the visitors data
# Initialize an empty list to hold the processed visitor data
processed_visitor_data = []

print("Processing visitor answers...")
for index, row in visitors_df.iterrows():
    visitor_id = row['id']
    visitor_email = row['email']
    visitor_gender = row['gender'] # Keep gender info

    try:
        # Load the JSON string into a Python list
        answers_list = json.loads(row['data'])

        # Iterate through each answer dictionary in the list
        for answer_data in answers_list:
            processed_visitor_data.append({
                'visitor_id': visitor_id,
                'visitor_email': visitor_email,
                'visitor_gender': visitor_gender,
                'questionId': answer_data.get('questionId'),
                'answerId': answer_data.get('answerId'), # May be empty/null if free text
                'answerValue': answer_data.get('answerValue'), # Captures free text or boolean answers
                'answerTypeId': answer_data.get('answerTypeId')
                # Add other relevant fields from answer_data if needed (like stepId)
            })
    except (json.JSONDecodeError, TypeError) as e:
        print(f"Error processing row index {index}, visitor_id {visitor_id}: {e}")
        # Decide how to handle errors: skip row, log it, etc.
        # Add a placeholder or skip if critical data is missing
        processed_visitor_data.append({
            'visitor_id': visitor_id,
             'visitor_email': visitor_email,
             'visitor_gender': visitor_gender,
             'questionId': None,
             'answerId': None,
             'answerValue': f"PARSE_ERROR: {e}",
             'answerTypeId': None
        })


# Create a new DataFrame from the processed data
visitor_answers_df = pd.DataFrame(processed_visitor_data)

visitor_answers_df
# Out:
# Processing visitor answers...
#                     visitor_id                       visitor_email  \
# 0     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# 1     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# 2     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# 3     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# 4     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# ...                        ...                                 ...
# 2822  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
# 2823  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
# 2824  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
# 2825  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
# 2826  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
#
#      visitor_gender                questionId                  answerId  \
# 0                 F  5c8a78336d41a10da4f730f0  5c8a78336d41a10da4f730f2
# 1                 F  6507de7e9e117216630ef7f2
# 2                 F  6507e0219e117216630ef7f5
# 3                 F  5c8a78336d41a10da4f733d8
# 4                 F  5c8a78336d41a10da4f733e2
# ...             ...                       ...                       ...
# 2822              M  5c8a78336d41a10da4f73358  5c8a78336d41a10da4f73359
# 2823              M  5c8a78336d41a10da4f732ed  5c8a78336d41a10da4f732ee
# 2824              M  5c8a78336d41a10da4f7336d  5c8a78336d41a10da4f73370
# 2825              M  5c8a78336d41a10da4f7337b  5c8a78336d41a10da4f7337c
# 2826              M  5c8a78336d41a10da4f7337e  5c8a78336d41a10da4f7337f
#
#                   answerValue answerTypeId
# 0                                   Answer
# 1     emilija+100_L8gA@bss.mk       Answer
# 2                        3138       Answer
# 3                         Eme       Answer
# 4                     Jankova       Answer
# ...                       ...          ...
# 2822                                Answer
# 2823                                Answer
# 2824                                Answer
# 2825                                Answer
# 2826                                Answer
#
# [2827 rows x 7 columns]

# %%
visitor_answers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2827 entries, 0 to 2826
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   visitor_id      2827 non-null   object
#  1   visitor_email   2827 non-null   object
#  2   visitor_gender  2827 non-null   object
#  3   questionId      2827 non-null   object
#  4   answerId        2827 non-null   object
#  5   answerValue     2827 non-null   object
#  6   answerTypeId    2827 non-null   object
# dtypes: object(7)
# memory usage: 154.7+ KB

# %%
print(f"Unique visitors in processed data: {visitor_answers_df['visitor_id'].nunique()}")
# Out:
# Unique visitors in processed data: 100

# %%
# Rename columns for clarity before merging
answers_df.rename(columns={'id': 'answerId_lookup', 'answer': 'answerText', 'questionId': 'questionId_from_answer'},inplace=True)
questions_df.rename(columns={'id': 'questionId_lookup', 'question': 'questionText'},inplace=True)

# %%
# Merge with questions
visitor_answers_merged_df = pd.merge(
    visitor_answers_df,
    questions_df[['questionId_lookup', 'questionText']],
    left_on='questionId',
    right_on='questionId_lookup',
    how='left'
)

visitor_answers_merged_df
# Out:
#                     visitor_id                       visitor_email  \
# 0     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# 1     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# 2     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# 3     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# 4     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# ...                        ...                                 ...
# 2822  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
# 2823  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
# 2824  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
# 2825  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
# 2826  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
#
#      visitor_gender                questionId                  answerId  \
# 0                 F  5c8a78336d41a10da4f730f0  5c8a78336d41a10da4f730f2
# 1                 F  6507de7e9e117216630ef7f2
# 2                 F  6507e0219e117216630ef7f5
# 3                 F  5c8a78336d41a10da4f733d8
# 4                 F  5c8a78336d41a10da4f733e2
# ...             ...                       ...                       ...
# 2822              M  5c8a78336d41a10da4f73358  5c8a78336d41a10da4f73359
# 2823              M  5c8a78336d41a10da4f732ed  5c8a78336d41a10da4f732ee
# 2824              M  5c8a78336d41a10da4f7336d  5c8a78336d41a10da4f73370
# 2825              M  5c8a78336d41a10da4f7337b  5c8a78336d41a10da4f7337c
# 2826              M  5c8a78336d41a10da4f7337e  5c8a78336d41a10da4f7337f
#
#                   answerValue answerTypeId         questionId_lookup  \
# 0                                   Answer                       NaN
# 1     emilija+100_L8gA@bss.mk       Answer                       NaN
# 2                        3138       Answer                       NaN
# 3                         Eme       Answer                       NaN
# 4                     Jankova       Answer                       NaN
# ...                       ...          ...                       ...
# 2822                                Answer                       NaN
# 2823                                Answer                       NaN
# 2824                                Answer  5c8a78336d41a10da4f7336d
# 2825                                Answer                       NaN
# 2826                                Answer                       NaN
#
#                                            questionText
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2822                                                NaN
# 2823                                                NaN
# 2824  What role do you play in the purchasing decisi...
# 2825                                                NaN
# 2826                                                NaN
#
# [2827 rows x 9 columns]

# %%
# Merge with answers - Use the answerId for mapping predefined answers
visitor_answers_merged_df = pd.merge(
    visitor_answers_merged_df,
    answers_df[['answerId_lookup', 'answerText']],
    left_on='answerId',
    right_on='answerId_lookup',
    how='left'
)

visitor_answers_merged_df
# Out:
#                     visitor_id                       visitor_email  \
# 0     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# 1     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# 2     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# 3     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# 4     67b70a9f2d21f543a1096602             emilija+100_L8gA@bss.mk
# ...                        ...                                 ...
# 2822  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
# 2823  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
# 2824  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
# 2825  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
# 2826  mv0j9yovwhgmtif9l1naciko  daniela.p+200_IzcX_CIHU@bss.com.mk
#
#      visitor_gender                questionId                  answerId  \
# 0                 F  5c8a78336d41a10da4f730f0  5c8a78336d41a10da4f730f2
# 1                 F  6507de7e9e117216630ef7f2
# 2                 F  6507e0219e117216630ef7f5
# 3                 F  5c8a78336d41a10da4f733d8
# 4                 F  5c8a78336d41a10da4f733e2
# ...             ...                       ...                       ...
# 2822              M  5c8a78336d41a10da4f73358  5c8a78336d41a10da4f73359
# 2823              M  5c8a78336d41a10da4f732ed  5c8a78336d41a10da4f732ee
# 2824              M  5c8a78336d41a10da4f7336d  5c8a78336d41a10da4f73370
# 2825              M  5c8a78336d41a10da4f7337b  5c8a78336d41a10da4f7337c
# 2826              M  5c8a78336d41a10da4f7337e  5c8a78336d41a10da4f7337f
#
#                   answerValue answerTypeId         questionId_lookup  \
# 0                                   Answer                       NaN
# 1     emilija+100_L8gA@bss.mk       Answer                       NaN
# 2                        3138       Answer                       NaN
# 3                         Eme       Answer                       NaN
# 4                     Jankova       Answer                       NaN
# ...                       ...          ...                       ...
# 2822                                Answer                       NaN
# 2823                                Answer                       NaN
# 2824                                Answer  5c8a78336d41a10da4f7336d
# 2825                                Answer                       NaN
# 2826                                Answer                       NaN
#
#                                            questionText  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2822                                                NaN
# 2823                                                NaN
# 2824  What role do you play in the purchasing decisi...
# 2825                                                NaN
# 2826                                                NaN
#
#                answerId_lookup     answerText
# 0                          NaN            NaN
# 1                          NaN            NaN
# 2                          NaN            NaN
# 3                          NaN            NaN
# 4                          NaN            NaN
# ...                        ...            ...
# 2822                       NaN            NaN
# 2823                       NaN            NaN
# 2824  5c8a78336d41a10da4f73370  Advisory role
# 2825                       NaN            NaN
# 2826                       NaN            NaN
#
# [2827 rows x 11 columns]

# %%
# Removing rows where questionId_lookup	questionTex answerId_lookup	answerText are null
visitor_answers_merged_df.dropna(subset=['questionId_lookup', 'questionText', 'answerId_lookup', 'answerText'], inplace=True)
# Reset index after dropping rows
visitor_answers_merged_df.reset_index(drop=True, inplace=True)
visitor_answers_merged_df
# Out:
#                    visitor_id                            visitor_email  \
# 0    67b70a9f2d21f543a1096602                  emilija+100_L8gA@bss.mk
# 1    67b70a9f2d21f543a1096602                  emilija+100_L8gA@bss.mk
# 2    67b70a9f2d21f543a1096602                  emilija+100_L8gA@bss.mk
# 3    67b70a9f2d21f543a1096602                  emilija+100_L8gA@bss.mk
# 4    67ada1ee197e604dd2722d1b  aleksandar.dimkov+mitt1_n5eA@bss.com.mk
# ..                        ...                                      ...
# 356  uud1nluegdqmisnfzpg75iqg       daniela.p+200_IzcX_QOfF@bss.com.mk
# 357  mv0j9yovwhgmtif9l1naciko       daniela.p+200_IzcX_CIHU@bss.com.mk
# 358  mv0j9yovwhgmtif9l1naciko       daniela.p+200_IzcX_CIHU@bss.com.mk
# 359  mv0j9yovwhgmtif9l1naciko       daniela.p+200_IzcX_CIHU@bss.com.mk
# 360  mv0j9yovwhgmtif9l1naciko       daniela.p+200_IzcX_CIHU@bss.com.mk
#
#     visitor_gender                questionId                  answerId  \
# 0                F  5c8a78336d41a10da4f730fe  5c8a78336d41a10da4f73100
# 1                F  5c8a78336d41a10da4f73227  5c8a78336d41a10da4f73244
# 2                F  5c8a78336d41a10da4f73253  5c8a78336d41a10da4f73291
# 3                F  5c8a78336d41a10da4f7336d  5c8a78336d41a10da4f73371
# 4                M  5c8a78336d41a10da4f730fe  5c8a78336d41a10da4f730ff
# ..             ...                       ...                       ...
# 356              M  5c8a78336d41a10da4f7336d  5c8a78336d41a10da4f73370
# 357              M  5c8a78336d41a10da4f730fe  5c8a78336d41a10da4f73100
# 358              M  5c8a78336d41a10da4f73227  5c8a78336d41a10da4f7323d
# 359              M  5c8a78336d41a10da4f73253  5c8a78336d41a10da4f73291
# 360              M  5c8a78336d41a10da4f7336d  5c8a78336d41a10da4f73370
#
#     answerValue answerTypeId         questionId_lookup  \
# 0                     Answer  5c8a78336d41a10da4f730fe
# 1                     Answer  5c8a78336d41a10da4f73227
# 2                     Answer  5c8a78336d41a10da4f73253
# 3                     Answer  5c8a78336d41a10da4f7336d
# 4                     Answer  5c8a78336d41a10da4f730fe
# ..          ...          ...                       ...
# 356                   Answer  5c8a78336d41a10da4f7336d
# 357                   Answer  5c8a78336d41a10da4f730fe
# 358                   Answer  5c8a78336d41a10da4f73227
# 359                   Answer  5c8a78336d41a10da4f73253
# 360                   Answer  5c8a78336d41a10da4f7336d
#
#                                           questionText  \
# 0                       Reason for Attending the Event
# 1    Which of the following best describes your job...
# 2    Please indicate your company's main area of bu...
# 3    What role do you play in the purchasing decisi...
# 4                       Reason for Attending the Event
# ..                                                 ...
# 356  What role do you play in the purchasing decisi...
# 357                     Reason for Attending the Event
# 358  Which of the following best describes your job...
# 359  Please indicate your company's main area of bu...
# 360  What role do you play in the purchasing decisi...
#
#               answerId_lookup                       answerText
# 0    5c8a78336d41a10da4f73100    To obtain general information
# 1    5c8a78336d41a10da4f73244                            Media
# 2    5c8a78336d41a10da4f73291                     Travel Agent
# 3    5c8a78336d41a10da4f73371                     No influence
# 4    5c8a78336d41a10da4f730ff  To source products and services
# ..                        ...                              ...
# 356  5c8a78336d41a10da4f73370                    Advisory role
# 357  5c8a78336d41a10da4f73100    To obtain general information
# 358  5c8a78336d41a10da4f7323d             Guided tour services
# 359  5c8a78336d41a10da4f73291                     Travel Agent
# 360  5c8a78336d41a10da4f73370                    Advisory role
#
# [361 rows x 11 columns]

# %%
# Drop redundant columns
visitor_answers_merged_df = visitor_answers_merged_df.drop(columns=['questionId_lookup', 'answerId_lookup','answerValue'])
visitor_answers_merged_df
# Out:
#                    visitor_id                            visitor_email  \
# 0    67b70a9f2d21f543a1096602                  emilija+100_L8gA@bss.mk
# 1    67b70a9f2d21f543a1096602                  emilija+100_L8gA@bss.mk
# 2    67b70a9f2d21f543a1096602                  emilija+100_L8gA@bss.mk
# 3    67b70a9f2d21f543a1096602                  emilija+100_L8gA@bss.mk
# 4    67ada1ee197e604dd2722d1b  aleksandar.dimkov+mitt1_n5eA@bss.com.mk
# ..                        ...                                      ...
# 356  uud1nluegdqmisnfzpg75iqg       daniela.p+200_IzcX_QOfF@bss.com.mk
# 357  mv0j9yovwhgmtif9l1naciko       daniela.p+200_IzcX_CIHU@bss.com.mk
# 358  mv0j9yovwhgmtif9l1naciko       daniela.p+200_IzcX_CIHU@bss.com.mk
# 359  mv0j9yovwhgmtif9l1naciko       daniela.p+200_IzcX_CIHU@bss.com.mk
# 360  mv0j9yovwhgmtif9l1naciko       daniela.p+200_IzcX_CIHU@bss.com.mk
#
#     visitor_gender                questionId                  answerId  \
# 0                F  5c8a78336d41a10da4f730fe  5c8a78336d41a10da4f73100
# 1                F  5c8a78336d41a10da4f73227  5c8a78336d41a10da4f73244
# 2                F  5c8a78336d41a10da4f73253  5c8a78336d41a10da4f73291
# 3                F  5c8a78336d41a10da4f7336d  5c8a78336d41a10da4f73371
# 4                M  5c8a78336d41a10da4f730fe  5c8a78336d41a10da4f730ff
# ..             ...                       ...                       ...
# 356              M  5c8a78336d41a10da4f7336d  5c8a78336d41a10da4f73370
# 357              M  5c8a78336d41a10da4f730fe  5c8a78336d41a10da4f73100
# 358              M  5c8a78336d41a10da4f73227  5c8a78336d41a10da4f7323d
# 359              M  5c8a78336d41a10da4f73253  5c8a78336d41a10da4f73291
# 360              M  5c8a78336d41a10da4f7336d  5c8a78336d41a10da4f73370
#
#     answerTypeId                                       questionText  \
# 0         Answer                     Reason for Attending the Event
# 1         Answer  Which of the following best describes your job...
# 2         Answer  Please indicate your company's main area of bu...
# 3         Answer  What role do you play in the purchasing decisi...
# 4         Answer                     Reason for Attending the Event
# ..           ...                                                ...
# 356       Answer  What role do you play in the purchasing decisi...
# 357       Answer                     Reason for Attending the Event
# 358       Answer  Which of the following best describes your job...
# 359       Answer  Please indicate your company's main area of bu...
# 360       Answer  What role do you play in the purchasing decisi...
#
#                           answerText
# 0      To obtain general information
# 1                              Media
# 2                       Travel Agent
# 3                       No influence
# 4    To source products and services
# ..                               ...
# 356                    Advisory role
# 357    To obtain general information
# 358             Guided tour services
# 359                     Travel Agent
# 360                    Advisory role
#
# [361 rows x 8 columns]

# %%
#Arrange the columns in a more logical order and save it in a final df
final_visitor_data = visitor_answers_merged_df[['visitor_id','visitor_email','visitor_gender','questionId','questionText','answerId','answerText','answerTypeId']].copy()
final_visitor_data
# Out:
#                    visitor_id                            visitor_email  \
# 0    67b70a9f2d21f543a1096602                  emilija+100_L8gA@bss.mk
# 1    67b70a9f2d21f543a1096602                  emilija+100_L8gA@bss.mk
# 2    67b70a9f2d21f543a1096602                  emilija+100_L8gA@bss.mk
# 3    67b70a9f2d21f543a1096602                  emilija+100_L8gA@bss.mk
# 4    67ada1ee197e604dd2722d1b  aleksandar.dimkov+mitt1_n5eA@bss.com.mk
# ..                        ...                                      ...
# 356  uud1nluegdqmisnfzpg75iqg       daniela.p+200_IzcX_QOfF@bss.com.mk
# 357  mv0j9yovwhgmtif9l1naciko       daniela.p+200_IzcX_CIHU@bss.com.mk
# 358  mv0j9yovwhgmtif9l1naciko       daniela.p+200_IzcX_CIHU@bss.com.mk
# 359  mv0j9yovwhgmtif9l1naciko       daniela.p+200_IzcX_CIHU@bss.com.mk
# 360  mv0j9yovwhgmtif9l1naciko       daniela.p+200_IzcX_CIHU@bss.com.mk
#
#     visitor_gender                questionId  \
# 0                F  5c8a78336d41a10da4f730fe
# 1                F  5c8a78336d41a10da4f73227
# 2                F  5c8a78336d41a10da4f73253
# 3                F  5c8a78336d41a10da4f7336d
# 4                M  5c8a78336d41a10da4f730fe
# ..             ...                       ...
# 356              M  5c8a78336d41a10da4f7336d
# 357              M  5c8a78336d41a10da4f730fe
# 358              M  5c8a78336d41a10da4f73227
# 359              M  5c8a78336d41a10da4f73253
# 360              M  5c8a78336d41a10da4f7336d
#
#                                           questionText  \
# 0                       Reason for Attending the Event
# 1    Which of the following best describes your job...
# 2    Please indicate your company's main area of bu...
# 3    What role do you play in the purchasing decisi...
# 4                       Reason for Attending the Event
# ..                                                 ...
# 356  What role do you play in the purchasing decisi...
# 357                     Reason for Attending the Event
# 358  Which of the following best describes your job...
# 359  Please indicate your company's main area of bu...
# 360  What role do you play in the purchasing decisi...
#
#                      answerId                       answerText answerTypeId
# 0    5c8a78336d41a10da4f73100    To obtain general information       Answer
# 1    5c8a78336d41a10da4f73244                            Media       Answer
# 2    5c8a78336d41a10da4f73291                     Travel Agent       Answer
# 3    5c8a78336d41a10da4f73371                     No influence       Answer
# 4    5c8a78336d41a10da4f730ff  To source products and services       Answer
# ..                        ...                              ...          ...
# 356  5c8a78336d41a10da4f73370                    Advisory role       Answer
# 357  5c8a78336d41a10da4f73100    To obtain general information       Answer
# 358  5c8a78336d41a10da4f7323d             Guided tour services       Answer
# 359  5c8a78336d41a10da4f73291                     Travel Agent       Answer
# 360  5c8a78336d41a10da4f73370                    Advisory role       Answer
#
# [361 rows x 8 columns]

# %% [markdown]
# ## --- Processing Exhibitor Data ---

# %%
exhibitors_df.head()
# Out:
#    exhibitorid                    Name                       MainCategories
# 0        90556          Turkey Travels                    52276|52280|52281
# 1        92462  Russian Travel Company  52273|52283|52289|52291|52298|52302
# 2        92491   Indian Travel Company                    52273|52274|52281
# 3        92492            Asia Tourism              52272|52276|52352|52358
# 4        92493     SriLanka Adventures                    52296|52327|52352

# %%
# Split the pipe-separated string into a list of category IDs
exhibitors_df['CategoryList'] = exhibitors_df['MainCategories'].apply(lambda x: x.split('|') if x else [])

# %%
exhibitors_df.head()
# Out:
#    exhibitorid                    Name                       MainCategories  \
# 0        90556          Turkey Travels                    52276|52280|52281
# 1        92462  Russian Travel Company  52273|52283|52289|52291|52298|52302
# 2        92491   Indian Travel Company                    52273|52274|52281
# 3        92492            Asia Tourism              52272|52276|52352|52358
# 4        92493     SriLanka Adventures                    52296|52327|52352
#
#                                  CategoryList
# 0                       [52276, 52280, 52281]
# 1  [52273, 52283, 52289, 52291, 52298, 52302]
# 2                       [52273, 52274, 52281]
# 3                [52272, 52276, 52352, 52358]
# 4                       [52296, 52327, 52352]

# %%
# Check if any empty category lists exist
exhibitors_df[exhibitors_df['CategoryList']=='[]']
# Out:
# Empty DataFrame
# Columns: [exhibitorid, Name, MainCategories, CategoryList]
# Index: []

# %%
# Explode the DataFrame to have one row per exhibitor-category pair
exhibitors_exploded_df = exhibitors_df.explode('CategoryList')
# Rename the column holding the single category ID
exhibitors_exploded_df.rename(columns={'CategoryList': 'categoryId'},inplace=True)

exhibitors_exploded_df.head()
# Out:
#    exhibitorid                    Name                       MainCategories  \
# 0        90556          Turkey Travels                    52276|52280|52281
# 0        90556          Turkey Travels                    52276|52280|52281
# 0        90556          Turkey Travels                    52276|52280|52281
# 1        92462  Russian Travel Company  52273|52283|52289|52291|52298|52302
# 1        92462  Russian Travel Company  52273|52283|52289|52291|52298|52302
#
#   categoryId
# 0      52276
# 0      52280
# 0      52281
# 1      52273
# 1      52283

# %%
exhibitor_categories_df.head()
# Out:
#    categoryId                        categoryName
# 0       52271           1. Accomodation providers
# 1       52272       1.1 Hotel / Hotel chain / Inn
# 2       52273  1.2 Apartments / Residential hotel
# 3       52274                  1.3 Hostel / Motel
# 4       52275                  1.4 Boarding house

# %%
exhibitor_categories_df
# Out:
#     categoryId                                    categoryName
# 0        52271                       1. Accomodation providers
# 1        52272                   1.1 Hotel / Hotel chain / Inn
# 2        52273              1.2 Apartments / Residential hotel
# 3        52274                              1.3 Hostel / Motel
# 4        52275                              1.4 Boarding house
# ..         ...                                             ...
# 91       52319                              9.1 Hotel designer
# 92       52320   9.2 Manufacturer / distributor of consumables
# 93       52321                                    9.3 Cleaning
# 94       52322  9.4 Security system manufacturer / distributor
# 95       52323      9.5 Equipment for restaurants and catering
#
# [96 rows x 2 columns]

# %%
# Get the parent category for each exhibitor based on the category name
def get_parent_category(row):
    category_name = row["categoryName"]
    
    if "." in category_name:  # Check if it's a subcategory
        parent_num = category_name.split(".")[0]  # Extract the main category number
        parent_row = exhibitor_categories_df[exhibitor_categories_df["categoryName"].str.match(f"^{parent_num}\D")].iloc[0]  # Find the parent category row
        return parent_row["categoryName"]
    
    return category_name  # If it's a parent category, keep it the same

exhibitor_categories_df["parentCategory"] = exhibitor_categories_df.apply(get_parent_category, axis=1)

exhibitor_categories_df
# Out:
#     categoryId                                    categoryName  \
# 0        52271                       1. Accomodation providers
# 1        52272                   1.1 Hotel / Hotel chain / Inn
# 2        52273              1.2 Apartments / Residential hotel
# 3        52274                              1.3 Hostel / Motel
# 4        52275                              1.4 Boarding house
# ..         ...                                             ...
# 91       52319                              9.1 Hotel designer
# 92       52320   9.2 Manufacturer / distributor of consumables
# 93       52321                                    9.3 Cleaning
# 94       52322  9.4 Security system manufacturer / distributor
# 95       52323      9.5 Equipment for restaurants and catering
#
#                             parentCategory
# 0                1. Accomodation providers
# 1                1. Accomodation providers
# 2                1. Accomodation providers
# 3                1. Accomodation providers
# 4                1. Accomodation providers
# ..                                     ...
# 91  9. Hotel equipment & service suppliers
# 92  9. Hotel equipment & service suppliers
# 93  9. Hotel equipment & service suppliers
# 94  9. Hotel equipment & service suppliers
# 95  9. Hotel equipment & service suppliers
#
# [96 rows x 3 columns]

# %%
# Ensure correct data type for merging
# Convert both categoryId columns to a common type (e.g., string or int)
# Check dtypes first! Let's assume they should be integers based on exhibitor_categories.csv
exhibitors_exploded_df['categoryId'] = pd.to_numeric(exhibitors_exploded_df['categoryId'], errors='coerce')
exhibitor_categories_df['categoryId'] = pd.to_numeric(exhibitor_categories_df['categoryId'], errors='coerce')

print(exhibitors_exploded_df['categoryId'].isnull().sum(), exhibitor_categories_df['categoryId'].isnull().sum())
# Out:
# 0 0

# %%
exhibitors_exploded_df['categoryId'] = exhibitors_exploded_df['categoryId'].astype(int)
exhibitor_categories_df['categoryId'] = exhibitor_categories_df['categoryId'].astype(int)

# %%
exhibitors_final_df = pd.merge(
    exhibitors_exploded_df,
    exhibitor_categories_df,
    on='categoryId',
    how='left'
)
exhibitors_final_df
# Out:
#      exhibitorid                    Name  \
# 0          90556          Turkey Travels
# 1          90556          Turkey Travels
# 2          90556          Turkey Travels
# 3          92462  Russian Travel Company
# 4          92462  Russian Travel Company
# ..           ...                     ...
# 178        17729   Sunny Travel Journeys
# 179        17729   Sunny Travel Journeys
# 180        17729   Sunny Travel Journeys
# 181        17729   Sunny Travel Journeys
# 182        17729   Sunny Travel Journeys
#
#                                         MainCategories  categoryId  \
# 0                                    52276|52280|52281       52276
# 1                                    52276|52280|52281       52280
# 2                                    52276|52280|52281       52281
# 3                  52273|52283|52289|52291|52298|52302       52273
# 4                  52273|52283|52289|52291|52298|52302       52283
# ..                                                 ...         ...
# 178  52271|52359|52304|52285|52282|52272|52329|5236...       52282
# 179  52271|52359|52304|52285|52282|52272|52329|5236...       52272
# 180  52271|52359|52304|52285|52282|52272|52329|5236...       52329
# 181  52271|52359|52304|52285|52282|52272|52329|5236...       52366
# 182  52271|52359|52304|52285|52282|52272|52329|5236...       52297
#
#                            categoryName                        parentCategory
# 0                      1.5 Resort hotel             1. Accomodation providers
# 1             2.1 Inbound tour operator                     2. Tour operators
# 2            2.2 Outbound tour operator                     2. Tour operators
# 3    1.2 Apartments / Residential hotel             1. Accomodation providers
# 4        2.4 Mass market tour operators                     2. Tour operators
# ..                                  ...                                   ...
# 178     2.3 Receptive / ground operator                     2. Tour operators
# 179       1.1 Hotel / Hotel chain / Inn             1. Accomodation providers
# 180                            10.5 Zoo                   10. Museums & parks
# 181           17.3 Banking, investments     17. Insurance companies & banking
# 182             5.5 Helicopter services  5. Transport services / air carriage
#
# [183 rows x 6 columns]

# %%
exhibitors_final_df = exhibitors_final_df[['exhibitorid', 'Name', 'categoryId', 'categoryName','parentCategory']].copy()
exhibitors_final_df.rename(columns={'Name': 'exhibitorName'}, inplace=True)
exhibitors_final_df
# Out:
#      exhibitorid           exhibitorName  categoryId  \
# 0          90556          Turkey Travels       52276
# 1          90556          Turkey Travels       52280
# 2          90556          Turkey Travels       52281
# 3          92462  Russian Travel Company       52273
# 4          92462  Russian Travel Company       52283
# ..           ...                     ...         ...
# 178        17729   Sunny Travel Journeys       52282
# 179        17729   Sunny Travel Journeys       52272
# 180        17729   Sunny Travel Journeys       52329
# 181        17729   Sunny Travel Journeys       52366
# 182        17729   Sunny Travel Journeys       52297
#
#                            categoryName                        parentCategory
# 0                      1.5 Resort hotel             1. Accomodation providers
# 1             2.1 Inbound tour operator                     2. Tour operators
# 2            2.2 Outbound tour operator                     2. Tour operators
# 3    1.2 Apartments / Residential hotel             1. Accomodation providers
# 4        2.4 Mass market tour operators                     2. Tour operators
# ..                                  ...                                   ...
# 178     2.3 Receptive / ground operator                     2. Tour operators
# 179       1.1 Hotel / Hotel chain / Inn             1. Accomodation providers
# 180                            10.5 Zoo                   10. Museums & parks
# 181           17.3 Banking, investments     17. Insurance companies & banking
# 182             5.5 Helicopter services  5. Transport services / air carriage
#
# [183 rows x 5 columns]

# %%
#Save Processed Data
final_visitor_data.to_csv(os.path.join(base_path, 'processed_visitors_answers.csv'), index=False)
exhibitors_final_df.to_csv(os.path.join(base_path, 'processed_exhibitors_categories.csv'), index=False)
